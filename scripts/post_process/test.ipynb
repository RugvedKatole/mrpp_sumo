# %%
import networkx as nx

iitb = nx.read_graphml("/home/arms04/catkin_ws/src/mrpp_sumo/graph_ml/iitb.graphml")
cair = nx.read_graphml("/home/arms04/catkin_ws/src/mrpp_sumo/graph_ml/cair.graphml")
grid = nx.read_graphml("/home/arms04/catkin_ws/src/mrpp_sumo/graph_ml/grid_5_5.graphml")

# %%
import matplotlib.pyplot as plt
fig,axes = plt.subplots(1,3,figsize=(75,25))
nx.draw(G=iitb)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/arms04/catkin_ws/src/mrpp_sumo/scripts/post_process/test.ipynb Cell 2' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/arms04/catkin_ws/src/mrpp_sumo/scripts/post_process/test.ipynb#ch0000001?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/home/arms04/catkin_ws/src/mrpp_sumo/scripts/post_process/test.ipynb#ch0000001?line=1'>2</a> fig,axes = plt.subplots(1,3,figsize=(75,25))
# ----> <a href='vscode-notebook-cell:/home/arms04/catkin_ws/src/mrpp_sumo/scripts/post_process/test.ipynb#ch0000001?line=2'>3</a> nx.draw(ax= axes[0,0],G=iitb)
#       <a href='vscode-notebook-cell:/home/arms04/catkin_ws/src/mrpp_sumo/scripts/post_process/test.ipynb#ch0000001?line=3'>4</a> plt.show()
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
